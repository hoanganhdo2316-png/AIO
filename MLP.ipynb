# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	MLP.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
import torch.nn as nn
from torchsummary import summary
import torch
import torch.optim as optim

#khai bao thu vien

# %%
model = nn.Sequential(

    nn.Linear(1,1),
    nn.Linear(1,1),
    nn.Sigmoid()
)

# %%
print(model)
# Out:
# Sequential(
#   (0): Linear(in_features=1, out_features=1, bias=True)
#   (1): Linear(in_features=1, out_features=1, bias=True)
#   (2): Sigmoid()
# )

# %%
summary(model, (1000000,1))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1           [-1, 1000000, 1]               2
#             Linear-2           [-1, 1000000, 1]               2
#            Sigmoid-3           [-1, 1000000, 1]               0
# ================================================================
# Total params: 4
# Trainable params: 4
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 3.81
# Forward/backward pass size (MB): 22.89
# Params size (MB): 0.00
# Estimated Total Size (MB): 26.70
# ----------------------------------------------------------------

# %%
for layer in model.children():
    print(layer.state_dict())
# Out:
# OrderedDict({'weight': tensor([[0.6563]]), 'bias': tensor([0.4676])})
# OrderedDict({'weight': tensor([[-0.9341]]), 'bias': tensor([-0.8710])})
# OrderedDict()

# %%
model = nn.Sequential(
    nn.Linear(2, 2),
    nn.Linear(2, 2),
    nn.Sigmoid()
)

# %%
summary(model,(10000000,2))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1          [-1, 10000000, 2]               6
#             Linear-2          [-1, 10000000, 2]               6
#            Sigmoid-3          [-1, 10000000, 2]               0
# ================================================================
# Total params: 12
# Trainable params: 12
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 76.29
# Forward/backward pass size (MB): 457.76
# Params size (MB): 0.00
# Estimated Total Size (MB): 534.06
# ----------------------------------------------------------------

# %%
for layer in model.children():
    print(layer.state_dict())
# Out:
# OrderedDict({'weight': tensor([[ 0.0346,  0.4485],
#         [ 0.1671, -0.5573]]), 'bias': tensor([0.1656, 0.4645])})
# OrderedDict({'weight': tensor([[-0.0612,  0.6609],
#         [ 0.3271, -0.5723]]), 'bias': tensor([ 0.4605, -0.6126])})
# OrderedDict()

# %%
x=torch.tensor([1,2])
y=torch.tensor([0])

x,y
# Out:
# (tensor([1, 2]), tensor([0]))

# %%
model= nn.Sequential(
    nn.Linear(2,2),
    nn.Linear(2,1),
    nn.Sigmoid()
)

# %%
print(model)
summary(model,(1,2))
# Out:
# Sequential(
#   (0): Linear(in_features=2, out_features=2, bias=True)
#   (1): Linear(in_features=2, out_features=2, bias=True)
#   (2): Sigmoid()
# )
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                 [-1, 1, 2]               6
#             Linear-2                 [-1, 1, 2]               6
#            Sigmoid-3                 [-1, 1, 2]               0
# ================================================================
# Total params: 12
# Trainable params: 12
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------

# %%
for layer in model.children():
    print(layer.state_dict())
# Out:
# OrderedDict({'weight': tensor([[ 0.0346,  0.4485],
#         [ 0.1671, -0.5573]]), 'bias': tensor([0.1656, 0.4645])})
# OrderedDict({'weight': tensor([[-0.0612,  0.6609],
#         [ 0.3271, -0.5723]]), 'bias': tensor([ 0.4605, -0.6126])})
# OrderedDict()

# %%
for p in model.parameters():
    nn.init.constant_(p,0.1)
